# %%
"""
========================================================
Compare Stochastic learning strategies for MLPClassifier
========================================================

This example visualizes some training loss curves for different stochastic
learning strategies, including SGD and Adam. Because of time-constraints, we
use several small datasets, for which L-BFGS might be more suitable. The
general trend shown in these examples seems to carry over to larger datasets,
however.

Note that those results can be highly dependent on the value of
``learning_rate_init``.
"""

print(__doc__)

import warnings

import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets
from sklearn.exceptions import ConvergenceWarning

# different learning rate schedules and momentum parameters
params = [{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'adam', 'learning_rate_init': 0.01}]

labels = ["constant learning-rate", "constant with momentum",
          "constant with Nesterov's momentum",
          "inv-scaling learning-rate", "inv-scaling with momentum",
          "inv-scaling with Nesterov's momentum", "adam"]

plot_args = [{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '--'},
             {'c': 'green', 'linestyle': '--'},
             {'c': 'blue', 'linestyle': '--'},
             {'c': 'black', 'linestyle': '-'}]


def plot_on_dataset(X, y, ax, name):
    # for each dataset, plot learning for each learning strategy
    print("\nlearning on dataset %s" % name)
    ax.set_title(name)

    X = MinMaxScaler().fit_transform(X)
    mlps = []
    if name == "digits":
        # digits is larger but converges fairly quickly
        max_iter = 15
    else:
        max_iter = 400

    for label, param in zip(labels, params):
        print("training: %s" % label)
        mlp = MLPRegressor(verbose=False, random_state=9,
                            max_iter=max_iter, **param)

        # some parameter combinations will not converge as can be seen on the
        # plots so they are ignored here
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning,
                                    module="sklearn")
            mlp.fit(X, y)

        mlps.append(mlp)
        print("Training set score: %f" % mlp.score(X, y))
        print("Training set loss: %f" % mlp.loss_)
    for mlp, label, args in zip(mlps, labels, plot_args):
        ax.plot(mlp.loss_curve_, label=label, **args)


fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# load / generate some toy datasets
iris = datasets.load_iris()
digits = datasets.load_digits()
data_sets = [(iris.data, iris.target),
             (digits.data, digits.target),
             datasets.make_circles(noise=0.2, factor=0.5, random_state=1),
             datasets.make_moons(noise=0.3, random_state=0)]

for ax, data, name in zip(axes.ravel(), data_sets, ['iris', 'digits',
                                                    'circles', 'moons']):
    plot_on_dataset(*data, ax=ax, name=name)

fig.legend(ax.get_lines(), labels, ncol=3, loc="upper center")
plt.show()
# Out:
# ========================================================
# Compare Stochastic learning strategies for MLPClassifier
# ========================================================
#
# This example visualizes some training loss curves for different stochastic
# learning strategies, including SGD and Adam. Because of time-constraints, we
# use several small datasets, for which L-BFGS might be more suitable. The
# general trend shown in these examples seems to carry over to larger datasets,
# however.
#
# Note that those results can be highly dependent on the value of
# ``learning_rate_init``.
#
#
# learning on dataset iris
# training: constant learning-rate
# Training set score: 0.922942
# Training set loss: 0.025737
# training: constant with momentum
# Training set score: 0.919917
# Training set loss: 0.030058
# training: constant with Nesterov's momentum
# Training set score: 0.945132
# Training set loss: 0.018334
# training: inv-scaling learning-rate
# Training set score: 0.539436
# Training set loss: 0.153621
# training: inv-scaling with momentum
# Training set score: -0.365063
# Training set loss: 0.597955
# training: inv-scaling with Nesterov's momentum
# Training set score: -1.315748
# Training set loss: 1.092009
# training: adam
# Training set score: 0.932191
# Training set loss: 0.022693
#
# learning on dataset digits
# training: constant learning-rate
# Training set score: 0.115174
# Training set loss: 4.075872
# training: constant with momentum
# Training set score: 0.027472
# Training set loss: 4.117726
# training: constant with Nesterov's momentum
# Training set score: -0.000054
# Training set loss: 4.386523
# training: inv-scaling learning-rate
# Training set score: -0.072492
# Training set loss: 4.405464
# training: inv-scaling with momentum
# Training set score: -0.188324
# Training set loss: 5.281220
# training: inv-scaling with Nesterov's momentum
# Training set score: -0.047214
# Training set loss: 4.339081
# training: adam
# Training set score: 0.715828
# Training set loss: 1.216269
#
# learning on dataset circles
# training: constant learning-rate
# Training set score: 0.058721
# Training set loss: 0.117759
# training: constant with momentum
# Training set score: 0.669714
# Training set loss: 0.041357
# training: constant with Nesterov's momentum
# Training set score: 0.472965
# Training set loss: 0.113515
# training: inv-scaling learning-rate
# Training set score: -0.035474
# Training set loss: 0.129497
# training: inv-scaling with momentum
# Training set score: -1.261025
# Training set loss: 0.320366
# training: inv-scaling with Nesterov's momentum
# Training set score: -2.362095
# Training set loss: 0.481420
# training: adam
# Training set score: 0.669006
# Training set loss: 0.041404
#
# learning on dataset moons
# training: constant learning-rate
# Training set score: 0.547495
# Training set loss: 0.056623
# training: constant with momentum
# Training set score: 0.571960
# Training set loss: 0.053592
# training: constant with Nesterov's momentum
# Training set score: 0.561798
# Training set loss: 0.054820
# training: inv-scaling learning-rate
# Training set score: -0.029200
# Training set loss: 0.128735
# training: inv-scaling with momentum
# Training set score: -0.990016
# Training set loss: 0.289684
# training: inv-scaling with Nesterov's momentum
# Training set score: -1.634138
# Training set loss: 0.392339
# training: adam
# Training set score: 0.609877
# Training set loss: 0.048846
